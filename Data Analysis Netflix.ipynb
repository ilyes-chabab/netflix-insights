# %% [markdown]
# # ANALYSE DES DONNEES NETFLIX
# Ceci est un exercice d'analyse de données et nous allons nous exercer sur un dataset de netflix allant jusqu'à Septembre 2021 .
#
# - Nous allons voir les infos que nous avons à dispositions
# - Nous allons les modifier
# - Et nous allons , sous forme de graphe à l'aide de librairies , analyser ces données .

# %%
import pandas

# %%
netflix_data = pandas.read_csv(r"C:\Users\mehdi\Downloads\netflix_titles.csv")

# %%
display(netflix_data.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
display(netflix_data.tail())
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# # Ce que nous avons fait
#     Nous avons importer la librairie Panda et exécuter le fichier csv qu'on va traiter , nous avons ensuite afficher les 5 premières et les 5 dernières lignes de ce fichier grâce à Display .

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Les infos du dataframe

# %%
netflix_data.shape
# Out:
# (8807, 12)

# %%
netflix_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # Types de données
#     On voit bien qu'il y a des données quantitatives avec la colonne release_year en int64 , et les données catégorielles qui représentent le reste .

# %%
missing_data = netflix_data.isnull().sum()

# %%
print(missing_data)
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
missing_percentage = (netflix_data.isnull().sum() / len(netflix_data)) * 100

# %%
print(missing_percentage)
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
import missingno as msno

# %%
import matplotlib.pyplot as plt

# %%
msno.matrix(netflix_data)
# Out:
# <Axes: >

# %%
plt.show()

# %%
random_observation = netflix_data.sample()

# %%
print(random_observation)
# Out:
#     show_id     type                    title director cast country  \
# 761    s762  TV Show  Human: The World Within      NaN  NaN     NaN
#
#        date_added  release_year rating  duration  \
# 761  June 4, 2021          2021  TV-PG  1 Season
#
#                            listed_in  \
# 761  Docuseries, Science & Nature TV
#
#                                            description
# 761  Cutting-edge science and captivating personal ...

# %%
netflix_data[netflix_data['title'] == 'Catch Me If You Can']
# Out:
#     show_id   type                title          director  \
# 329    s330  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                   cast                country  \
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...  United States, Canada
#
#          date_added  release_year rating duration listed_in  \
# 329  August 1, 2021          2002  PG-13  142 min    Dramas
#
#                                            description
# 329  An FBI agent makes it his mission to put cunni...

# %%
netflix_data_triee = netflix_data.sort_values(by='release_year', ascending=False)

# %%
film_netflix_data = netflix_data_triee[netflix_data_triee['type'] == 'Movie']

# %%
most_recent_film = film_netflix_data.iloc[0]['title']

# %%
print("Nom du film le plus récent : ", most_recent_film)
# Out:
# Nom du film le plus récent :  Ali & Ratu Ratu Queens

# %%
serie_netflix_data = netflix_data_triee[netflix_data_triee['type'] == 'TV Show']

# %%
most_recent_TVShow = serie_netflix_data.iloc[0]['title']

# %%
print("Nom de la série la plus récente : ", most_recent_TVShow)
# Out:
# Nom de la série la plus récente :  Sweet Tooth

# %%
netflix_data['date_added'] = pandas.to_datetime(netflix_data['date_added'], format='%B %d, %Y',errors='coerce')

# %%
print(netflix_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None

# %%
netflix_data["duration"] = netflix_data["duration"].str.replace(r'[a-zA-Z]+'," ", regex=True)

# %%
print(netflix_data)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_data['listed_in'] = netflix_data['listed_in'].str.split(', ')

# %%
print(netflix_data.info)
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
print(netflix_data['type'].unique())
# Out:
# ['Movie' 'TV Show']

# %%
print(netflix_data['country'].unique())
# Out:
# ['United States' 'South Africa' nan 'India'
#  'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia'
#  'United Kingdom' 'Germany, Czech Republic' 'Mexico' 'Turkey' 'Australia'
#  'United States, India, France' 'Finland' 'China, Canada, United States'
#  'South Africa, United States, Japan' 'Nigeria' 'Japan'
#  'Spain, United States' 'France' 'Belgium' 'United Kingdom, United States'
#  'United States, United Kingdom' 'France, United States' 'South Korea'
#  'Spain' 'United States, Singapore' 'United Kingdom, Australia, France'
#  'United Kingdom, Australia, France, United States'
#  'United States, Canada' 'Germany, United States'
#  'South Africa, United States' 'United States, Mexico'
#  'United States, Italy, France, Japan'
#  'United States, Italy, Romania, United Kingdom'
#  'Australia, United States' 'Argentina, Venezuela'
#  'United States, United Kingdom, Canada' 'China, Hong Kong' 'Russia'
#  'Canada' 'Hong Kong' 'United States, China, Hong Kong'
# ...

# %%
print(netflix_data['release_year'].unique())
# Out:
# [2020 2021 1993 2018 1996 1998 1997 2010 2013 2017 1975 1978 1983 1987
#  2012 2001 2014 2002 2003 2004 2011 2008 2009 2007 2005 2006 1994 2015
#  2019 2016 1982 1989 1990 1991 1999 1986 1992 1984 1980 1961 2000 1995
#  1985 1976 1959 1988 1981 1972 1964 1945 1954 1979 1958 1956 1963 1970
#  1973 1925 1974 1960 1966 1971 1962 1969 1977 1967 1968 1965 1946 1942
#  1955 1944 1947 1943]

# %%
print(netflix_data['rating'].unique())
# Out:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' nan 'TV-Y7-FV' 'UR']

# %%
flattened_listed_in = netflix_data['listed_in'].explode()

# %%
unique_listed_in = flattened_listed_in.unique()

# %%
print(unique_listed_in)
# Out:
# ['Documentaries' 'International TV Shows' 'TV Dramas' 'TV Mysteries'
#  'Crime TV Shows' 'TV Action & Adventure' 'Docuseries' 'Reality TV'
#  'Romantic TV Shows' 'TV Comedies' 'TV Horror' 'Children & Family Movies'
#  'Dramas' 'Independent Movies' 'International Movies' 'British TV Shows'
#  'Comedies' 'Spanish-Language TV Shows' 'Thrillers' 'Romantic Movies'
#  'Music & Musicals' 'Horror Movies' 'Sci-Fi & Fantasy' 'TV Thrillers'
#  "Kids' TV" 'Action & Adventure' 'TV Sci-Fi & Fantasy' 'Classic Movies'
#  'Anime Features' 'Sports Movies' 'Anime Series' 'Korean TV Shows'
#  'Science & Nature TV' 'Teen TV Shows' 'Cult Movies' 'TV Shows'
#  'Faith & Spirituality' 'LGBTQ Movies' 'Stand-Up Comedy' 'Movies'
#  'Stand-Up Comedy & Talk Shows' 'Classic & Cult TV']

# %%
directors = netflix_data['director'].value_counts()

# %%
multiple_directors = directors[directors > 1]

# %%
print(multiple_directors)
# Out:
# director
# Rajiv Chilaka                 19
# Raúl Campos, Jan Suter        18
# Marcus Raboy                  16
# Suhas Kadav                   16
# Jay Karas                     14
#                               ..
# Abhijit Panse                  2
# Jose Manuel Colón              2
# Rhys Thomas                    2
# Rizal Mantovani                2
# Nawapol Thamrongrattanarit     2
# Name: count, Length: 867, dtype: int64

# %%
netflix_data["date_added"] = pandas.to_datetime(netflix_data["date_added"], format='%B %d, %Y')

# %%
films = netflix_data[netflix_data["type"]=="Movie"]

# %%
series = netflix_data[netflix_data["type"]=="TV Show"]

# %%
netflix_data["film_par_an"] = films["date_added"].dt.year

# %%
netflix_data["series_par_an"] = series["date_added"].dt.year

# %%
films_par_annee = netflix_data.groupby("film_par_an").size()

# %%
print("listes de films et series sortis chaque années sur netflix : ")
display(films_par_annee)
# Out:
# listes de films et series sortis chaque années sur netflix :
# film_par_an
# 2008.0       1
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0       6
# 2014.0      19
# 2015.0      56
# 2016.0     253
# 2017.0     839
# 2018.0    1237
# 2019.0    1424
# 2020.0    1284
# 2021.0     993
# dtype: int64

# %%
series_par_annee = netflix_data.groupby("series_par_an").size()

# %%
print(series_par_annee)
# Out:
# series_par_an
# 2008.0      1
# 2013.0      4
# 2014.0      4
# 2015.0     17
# 2016.0    165
# 2017.0    325
# 2018.0    388
# 2019.0    575
# 2020.0    594
# 2021.0    505
# dtype: int64

# %%
counts = netflix_data["type"].value_counts()

# %%
print(counts)
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title('Répartition du type d\'oeuvre')
plt.show()

# %%
counts = netflix_data["country"].value_counts()

# %%
print(counts)
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
plt.pie(counts)
plt.title('Répartition des oeuvres par pays')
plt.show()

# %%
counts = netflix_data["release_year"].value_counts()

# %%
print(counts)
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
plt.pie(counts)
plt.title('répartition du nombre d\'oeuvres par années')
plt.show()

# %%
counts = netflix_data["rating"].value_counts()

# %%
print(counts)
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
plt.pie(counts)
plt.title('répartition du rating')
plt.show()

# %%
films = netflix_data[netflix_data["type"]=="Movie"]

# %%
series = netflix_data[netflix_data["type"]=="TV Show"]

# %%
counts_films = films["duration"].value_counts()

# %%
counts_series = series["duration"].value_counts()

# %%
print(counts_films)
plt.pie(counts_films)
plt.title('La répartition de la durée des films du dataset,')
plt.show()
# Out:
# duration
# 90       152
# 94       146
# 93       146
# 97       146
# 91       144
#         ...
# 212        1
# 8          1
# 186        1
# 193        1
# 191        1
# Name: count, Length: 205, dtype: int64

# %%
print(counts_series)
plt.pie(counts_series)
plt.title('La répartition de la durée des series du dataset,')
plt.show()
# Out:
# duration
# 1       1793
# 2        425
# 3        199
# 4         95
# 5         65
# 6         33
# 7         23
# 8         17
# 9          9
# 10         7
# 13         3
# 15         2
# 12         2
# 11         2
# 17         1
# Name: count, dtype: int64

# %%
counts = netflix_data["listed_in"].value_counts()

# %%
print(counts)
# Out:
# listed_in
# [Dramas, International Movies]                          362
# [Documentaries]                                         359
# [Stand-Up Comedy]                                       334
# [Comedies, Dramas, International Movies]                274
# [Dramas, Independent Movies, International Movies]      252
#                                                        ...
# [Kids' TV, TV Action & Adventure, TV Dramas]              1
# [TV Comedies, TV Dramas, TV Horror]                       1
# [Children & Family Movies, Comedies, LGBTQ Movies]        1
# [Kids' TV, Spanish-Language TV Shows, Teen TV Shows]      1
# [Cult Movies, Dramas, Thrillers]                          1
# Name: count, Length: 514, dtype: int64

# %%
plt.pie(counts)
plt.title('La répartition des genres d\'œuvres du dataset,')
plt.show()

# %%
netflix_data["duration"] = netflix_data["duration"].str.extract('(\d+)').astype(float)

# %%
top_films = netflix_data[netflix_data["type"] == "Movie"].sort_values(by="duration", ascending=False).head(5)

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_films["title"], top_films["duration"])
plt.xlabel('Titre du film')
plt.ylabel('Nombre de minutes')
plt.title('Top 5 des films les plus longues')
plt.xticks(rotation=45, ha='right')  # Rotation des étiquettes sur l'axe des x
plt.tight_layout()  # Ajustement automatique de la disposition pour éviter la superposition
plt.show()

# %%
top_films = netflix_data[netflix_data["type"] == "TV Show"].sort_values(by="duration", ascending=False).head(5)

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_films["title"], top_films["duration"])
plt.xlabel('Titre de la série')
plt.ylabel('Nombre de saisons')
plt.title('Top 5 des séries les plus longues')
plt.xticks(rotation=45, ha='right')  # Rotation des étiquettes sur l'axe des x
plt.tight_layout()  # Ajustement automatique de la disposition pour éviter la superposition
plt.show()

# %%
oeuvres_francais = netflix_data[netflix_data["country"]=="France"]

# %%
directeur_francais = oeuvres_francais["director"].value_counts()

# %%
print(directeur_francais)
plt.pie(directeur_francais)
plt.title('La répartition des “directors” des œuvres françaises')
plt.show()
# Out:
# director
# Thierry Donard                    5
# Florent Bodin                     2
# Jean-Patrick Benes                1
# Benjamin Weill                    1
# Julien Rambaldi                   1
#                                  ..
# Jean-Claude Flamand-Barny         1
# Yacine Belhousse                  1
# Christophe Charrier               1
# Grand Corps Malade, Mehdi Idir    1
# Laurent Cantet                    1
# Name: count, Length: 76, dtype: int64

# %%
oeuvre_par_date = netflix_data["date_added"].value_counts()

# %%
print(oeuvre_par_date)
plt.pie(oeuvre_par_date)
plt.title('La répartition des œuvres en fonction de la date d’ajout au catalogue.')
plt.show()
# Out:
# date_added
# 2020-01-01    109
# 2019-11-01     89
# 2018-03-01     75
# 2019-12-31     74
# 2018-10-01     71
#              ...
# 2017-04-04      1
# 2017-03-28      1
# 2017-03-07      1
# 2017-02-27      1
# 2020-01-11      1
# Name: count, Length: 1699, dtype: int64

# %% [markdown]
# # En conclusion ,
# On peut dire que Netflix varie beaucoup son catalogue avec une multitude de genre , de nombreux réalisateurs et cela grâce à une abondance d'ajouts de films et séries par an énormes depuis les années 2018 .
#
# On peut noter tout de même une domination des états unis, de l'Inde et des pays asiatiques dans l'exportation de films et séries .
# Aussi on remarque qu'il y a beaucoup plus de films présents sur netflix que de séries .
#
# Il y a aussi une légére supériorité au niveau du "Rating" des films et séries Netflix , c'est à dire qu'on remarque assez vite le public visé , qui est assez axé sur les adolescents et les jeunes adultes .
#
# Ces mêmes personnes sont les plus à mêmes à consommer une saison de série assez rapidement , on peut donc faire un lien entre le public visé et le nombre important de série qui ne comporte qu'une seule saison .
